# %% [markdown]
#  # Tests on PDA

# %%
from jove.SystemImports import *
from jove.DotBashers    import *
from jove.Def_md2mc     import *
from jove.Def_PDA       import *

# %% [markdown]
# <b> Question 5 </b>

# %%
q5 = md2mc('''
PDA 

IF   : a,'';a# | b,'';b# | c,'';c#                    -> work        
work : a,a;aa | a,b;'' | b,a;'' | a,c;'' | c,a;''  -> work
work : c,c;cc | b,b;bb | c,b;cb | b,c;bc           -> work
work : '', # ;''                                   -> IF           

''')
DFq5 = dotObj_pda(q5, FuseEdges=True)
DFq5

# %%
explore_pda("baac", q5)
# Out:
# String baac accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('IF', '', '#')
# Reached as follows:
# ->  ('IF', 'baac', '#')
# ->  ('work', 'aac', 'b##')
# ->  ('work', 'ac', '##')
# ->  ('IF', 'ac', '#')
# ->  ('work', 'c', 'a##')
# ->  ('work', '', '##')
# ->  ('IF', '', '#') .

# %%
explore_pda("abacabbcbccccbaaaaaaaa", q5)
# Out:
# String abacabbcbccccbaaaaaaaa accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('IF', '', '#')
# Reached as follows:
# ->  ('IF', 'abacabbcbccccbaaaaaaaa', '#')
# ->  ('work', 'bacabbcbccccbaaaaaaaa', 'a##')
# ->  ('work', 'acabbcbccccbaaaaaaaa', '##')
# ->  ('IF', 'acabbcbccccbaaaaaaaa', '#')
# ->  ('work', 'cabbcbccccbaaaaaaaa', 'a##')
# ->  ('work', 'abbcbccccbaaaaaaaa', '##')
# ->  ('IF', 'abbcbccccbaaaaaaaa', '#')
# ->  ('work', 'bbcbccccbaaaaaaaa', 'a##')
# ->  ('work', 'bcbccccbaaaaaaaa', '##')
# ->  ('IF', 'bcbccccbaaaaaaaa', '#')
# ->  ('work', 'cbccccbaaaaaaaa', 'b##')
# ->  ('work', 'bccccbaaaaaaaa', 'cb##')
# ->  ('work', 'ccccbaaaaaaaa', 'bcb##')
# ->  ('work', 'cccbaaaaaaaa', 'cbcb##')
# ->  ('work', 'ccbaaaaaaaa', 'ccbcb##')
# ->  ('work', 'cbaaaaaaaa', 'cccbcb##')
# ->  ('work', 'baaaaaaaa', 'ccccbcb##')
# ->  ('work', 'aaaaaaaa', 'bccccbcb##')
# ->  ('work', 'aaaaaaa', 'ccccbcb##')
# ->  ('work', 'aaaaaa', 'cccbcb##')
# ...

# %%
explore_pda("aaaabaacabbcbccccbaaaa", q5)
# Out:
# String aaaabaacabbcbccccbaaaa accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('IF', '', '#')
# Reached as follows:
# ->  ('IF', 'aaaabaacabbcbccccbaaaa', '#')
# ->  ('work', 'aaabaacabbcbccccbaaaa', 'a##')
# ->  ('work', 'aabaacabbcbccccbaaaa', 'aa##')
# ->  ('work', 'abaacabbcbccccbaaaa', 'aaa##')
# ->  ('work', 'baacabbcbccccbaaaa', 'aaaa##')
# ->  ('work', 'aacabbcbccccbaaaa', 'aaa##')
# ->  ('work', 'acabbcbccccbaaaa', 'aaaa##')
# ->  ('work', 'cabbcbccccbaaaa', 'aaaaa##')
# ->  ('work', 'abbcbccccbaaaa', 'aaaa##')
# ->  ('work', 'bbcbccccbaaaa', 'aaaaa##')
# ->  ('work', 'bcbccccbaaaa', 'aaaa##')
# ->  ('work', 'cbccccbaaaa', 'aaa##')
# ->  ('work', 'bccccbaaaa', 'aa##')
# ->  ('work', 'ccccbaaaa', 'a##')
# ->  ('work', 'cccbaaaa', '##')
# ->  ('IF', 'cccbaaaa', '#')
# ->  ('work', 'ccbaaaa', 'c##')
# ->  ('work', 'cbaaaa', 'cc##')
# ->  ('work', 'baaaa', 'ccc##')
# ->  ('work', 'aaaa', 'bccc##')
# ->  ('work', 'aaa', 'ccc##')
# ...

# %% [markdown]
# <b> Question 6 </b>

# %%
q6 = md2mc('''
PDA 

I  : a,a;aa  | b,b;bb | a, #; a# | b,#;b# | c,c;cc | c, #; c# | a, c; ''| c, a; '' -> I
I  : a, b; ''| b, a; ''                                         -> W1
I  : '', #; #                                                   -> F
W1 : '',a; ''| a,b; b | a, #; #                                 -> I
W1 : b,b; bb | b, #; b# | c,c;cc | c, #; c# | a, c; ''| c, a; '' -> W1

''')
DOq6 = dotObj_pda(q6, FuseEdges=True)
DOq6

# %%
explore_pda("", q6)
# Out:
# String  accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('F', '', '#')
# Reached as follows:
# ->  ('I', '', '#')
# ->  ('F', '', '#') .

# %%
explore_pda("aabbaa", q6)
# Out:
# String aabbaa accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('F', '', '#')
# Reached as follows:
# ->  ('I', 'aabbaa', '#')
# ->  ('I', 'abbaa', 'a#')
# ->  ('I', 'bbaa', 'aa#')
# ->  ('W1', 'baa', 'a#')
# ->  ('I', 'baa', '#')
# ->  ('I', 'aa', 'b#')
# ->  ('W1', 'a', '#')
# ->  ('I', '', '#')
# ->  ('F', '', '#') .

# %%
explore_pda("acacacac", q6)
# Out:
# String acacacac accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('F', '', '#')
# Reached as follows:
# ->  ('I', 'acacacac', '#')
# ->  ('I', 'cacacac', 'a#')
# ->  ('I', 'acacac', '#')
# ->  ('I', 'cacac', 'a#')
# ->  ('I', 'acac', '#')
# ->  ('I', 'cac', 'a#')
# ->  ('I', 'ac', '#')
# ->  ('I', 'c', 'a#')
# ->  ('I', '', '#')
# ->  ('F', '', '#') .

# %%
explore_pda("ababaacacaca", q6)
# Out:
# String ababaacacaca accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('F', '', '#')
# Reached as follows:
# ->  ('I', 'ababaacacaca', '#')
# ->  ('I', 'babaacacaca', 'a#')
# ->  ('W1', 'abaacacaca', '#')
# ->  ('I', 'baacacaca', '#')
# ->  ('I', 'aacacaca', 'b#')
# ->  ('W1', 'acacaca', '#')
# ->  ('I', 'cacaca', '#')
# ->  ('I', 'acaca', 'c#')
# ->  ('I', 'caca', '#')
# ->  ('I', 'aca', 'c#')
# ->  ('I', 'ca', '#')
# ->  ('I', 'a', 'c#')
# ->  ('I', '', '#')
# ->  ('F', '', '#') .

# %%
explore_pda("acabacabacabaaa", q6)
# Out:
# String acabacabacabaaa accepted by your PDA in 1 ways :-)
# Here are the ways:
# Final state  ('F', '', '#')
# Reached as follows:
# ->  ('I', 'acabacabacabaaa', '#')
# ->  ('I', 'cabacabacabaaa', 'a#')
# ->  ('I', 'abacabacabaaa', '#')
# ->  ('I', 'bacabacabaaa', 'a#')
# ->  ('W1', 'acabacabaaa', '#')
# ->  ('I', 'cabacabaaa', '#')
# ->  ('I', 'abacabaaa', 'c#')
# ->  ('I', 'bacabaaa', '#')
# ->  ('I', 'acabaaa', 'b#')
# ->  ('W1', 'cabaaa', '#')
# ->  ('W1', 'abaaa', 'c#')
# ->  ('W1', 'baaa', '#')
# ->  ('W1', 'aaa', 'b#')
# ->  ('I', 'aa', 'b#')
# ->  ('W1', 'a', '#')
# ->  ('I', '', '#')
# ->  ('F', '', '#') .

# %% [markdown]
# Examples of Question 5

# %%
explore_pda("baac", q6)
# Out:
# String baac rejected by your PDA :-(
# Visited states are:
# {('F', 'baac', '#'), ('I', 'baac', '#'), ('I', 'c', '#'), ('F', 'c', '#'), ('I', 'aac', 'b#'), ('I', '', 'c#'), ('W1', 'ac', '#')}

# %%
explore_pda("abacabbcbccccbaaaaaaaa", q6)
# Out:
# String abacabbcbccccbaaaaaaaa rejected by your PDA :-(
# Visited states are:
# {('F', 'cabbcbccccbaaaaaaaa', '#'), ('F', 'abacabbcbccccbaaaaaaaa', '#'), ('I', 'bbcbccccbaaaaaaaa', '#'), ('I', 'cbccccbaaaaaaaa', 'bb#'), ('W1', 'acabbcbccccbaaaaaaaa', '#'), ('I', 'abacabbcbccccbaaaaaaaa', '#'), ('I', 'cabbcbccccbaaaaaaaa', '#'), ('F', 'bbcbccccbaaaaaaaa', '#'), ('I', 'bacabbcbccccbaaaaaaaa', 'a#'), ('I', 'bcbccccbaaaaaaaa', 'b#'), ('I', 'abbcbccccbaaaaaaaa', 'c#')}

# %%
explore_pda("aaaabaacabbcbccccbaaaa", q6)
# Out:
# String aaaabaacabbcbccccbaaaa rejected by your PDA :-(
# Visited states are:
# {('I', 'aacabbcbccccbaaaa', 'aa#'), ('I', 'bbcbccccbaaaa', 'aaaa#'), ('I', 'cabbcbccccbaaaa', 'aaaa#'), ('I', 'cbccccbaaaa', '#'), ('I', 'bcbccccbaaaa', 'aa#'), ('F', 'cbccccbaaaa', '#'), ('W1', 'aacabbcbccccbaaaa', 'aaa#'), ('I', 'abaacabbcbccccbaaaa', 'aaa#'), ('F', 'aaaabaacabbcbccccbaaaa', '#'), ('W1', 'bccccbaaaa', '#'), ('I', 'aabaacabbcbccccbaaaa', 'aa#'), ('I', 'acabbcbccccbaaaa', 'aaa#'), ('I', 'aaaabaacabbcbccccbaaaa', '#'), ('W1', 'cbccccbaaaa', 'a#'), ('I', 'baacabbcbccccbaaaa', 'aaaa#'), ('I', 'bccccbaaaa', 'c#'), ('I', 'abbcbccccbaaaa', 'aaa#'), ('W1', 'ccccbaaaa', 'b#'), ('I', 'aaabaacabbcbccccbaaaa', 'a#'), ('W1', 'bcbccccbaaaa', 'aaa#')}
